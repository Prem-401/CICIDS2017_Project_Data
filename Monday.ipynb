# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/DOS_Project/data_raw/Monday-WorkingHours.csv")
df.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              49188               4                   2
# 1              49188               1                   2
# 2              49188               1                   2
# 3              49188               1                   2
# 4              49486               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        0                           12
# 2                        0                           12
# 3                        0                           12
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             0                       6
# 2                             0                       6
# ...

# %% [markdown]
# # Visualizing class Distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x=' Label', data=df)
plt.title("Label Distribution (Normal vs Attack)")
plt.show()

# %%
df.columns
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
# ...

# %%
df[' Label'].value_counts()
# Out:
#  Label
# BENIGN    529918
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
#  Destination Port              0
#  Flow Duration                 0
#  Total Fwd Packets             0
#  Total Backward Packets        0
# Total Length of Fwd Packets    0
#                               ..
# Idle Mean                      0
#  Idle Std                      0
#  Idle Max                      0
#  Idle Min                      0
#  Label                         0
# Length: 79, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529918 entries, 0 to 529917
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0    Destination Port             529918 non-null  int64
#  1    Flow Duration                529918 non-null  int64
#  2    Total Fwd Packets            529918 non-null  int64
#  3    Total Backward Packets       529918 non-null  int64
#  4   Total Length of Fwd Packets   529918 non-null  int64
#  5    Total Length of Bwd Packets  529918 non-null  int64
#  6    Fwd Packet Length Max        529918 non-null  int64
#  7    Fwd Packet Length Min        529918 non-null  int64
#  8    Fwd Packet Length Mean       529918 non-null  float64
#  9    Fwd Packet Length Std        529918 non-null  float64
#  10  Bwd Packet Length Max         529918 non-null  int64
#  11   Bwd Packet Length Min        529918 non-null  int64
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df['Label'] = df['Label'].apply(lambda x: 0)

# %%
df['Label'].value_counts()
# Out:
# Label
# 0    529918
# Name: count, dtype: int64

# %%
# Save the cleaned dataset into Google Drive folder 'DOS_Project'
output_path = '/content/drive/MyDrive/DOS_Project/data_cleaned/monday_cleaned.csv'
df.to_csv(output_path, index=False)

print(f" File saved successfully at: {output_path}")
# Out:
#  File saved successfully at: /content/drive/MyDrive/DOS_Project/data_cleaned/monday_cleaned.csv

# %%
# !find /content/drive/MyDrive -type f
# Out:
# /content/drive/MyDrive/DOS_Project/data_raw/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
# /content/drive/MyDrive/DOS_Project/data_raw/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
# /content/drive/MyDrive/DOS_Project/data_raw/Friday-WorkingHours-Morning.pcap_ISCX.csv
# /content/drive/MyDrive/DOS_Project/data_raw/Tuesday-WorkingHours.pcap_ISCX.csv
# /content/drive/MyDrive/DOS_Project/data_raw/Wednesday-workingHours.pcap_ISCX.csv
# /content/drive/MyDrive/DOS_Project/data_raw/Monday-WorkingHours.csv
# /content/drive/MyDrive/DOS_Project/data_cleaned/tuesday_cleaned.csv
# /content/drive/MyDrive/DOS_Project/data_cleaned/monday_cleaned.csv
# /content/drive/MyDrive/DOS_Project/data_cleaned/wednesday_cleaned.csv
# /content/drive/MyDrive/DOS_Project/data_cleaned/Friday3.csv
# /content/drive/MyDrive/DOS_Project/data_cleaned/Friday1.csv
# /content/drive/MyDrive/DOS_Project/data_cleaned/Friday2.csv
# /content/drive/MyDrive/DOS_Project/data_cleaned/Final_cleaned_dataset.csv
# ...
